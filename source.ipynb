# %%
import pandas as pd

df = pd.read_excel('data.xlsx')
#print(df.columns)
df.columns = ['Year', 'Median house price', 'Westpac: 4 year forecast','Joe Bloggs: 2 year forecast', 'Harry Spent: 5 year forecast']

# %%
# Checking the data types
col = 'Median house price'
unique_types = df[col].apply(type).unique()
indices = df.index[df[col].apply(lambda x: isinstance(x, str))].tolist()
# 13
df.at[13,col] = 760000

# %%
# Checking the data types
col = 'Westpac: 4 year forecast'
unique_types = df[col].apply(type).unique()
indices = df.index[df[col].apply(lambda x: isinstance(x, str))].tolist()

# 12
df.at[12,col] = 0.15

# %%
# Checking the data types
col = 'Joe Bloggs: 2 year forecast'
unique_types = df[col].apply(type).unique()
indices = df.index[df[col].apply(lambda x: isinstance(x, int))].tolist()

print(unique_types)
print(indices)

#1
df.at[1,col] = 0.34

#6
df.at[6,col] = 0.15
# Out:
# [<class 'float'> <class 'str'> <class 'int'>]
# [6]

# %%
col = 'Harry Spent: 5 year forecast'
unique_types = df[col].apply(type).unique()
indices = df.index[df[col].apply(lambda x: isinstance(x, int))].tolist()

print(unique_types)
print(indices)
# Out:
# [<class 'float'>]
# []

# %%
df
# Out:
#     Year Median house price Westpac: 4 year forecast  \
# 0   2011             340000                     0.56
# 1   2012             370000                     0.53
# 2   2013             350000                      NaN
# 3   2014             420000                     0.13
# 4   2015             425000                     0.33
# 5   2016             500000                    -0.05
# 6   2017             520000                     0.45
# 7   2018             550000                     0.34
# 8   2019             596000                     0.34
# 9   2020             610000                      0.2
# 10  2021             660000                     -0.2
# 11  2022             720000                     0.15
# 12  2023              73000                     0.15
# 13  2024             760000                     -0.1
#
#    Joe Bloggs: 2 year forecast  Harry Spent: 5 year forecast
# 0                         0.23                         -0.20
# ...
